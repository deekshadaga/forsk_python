# %% [markdown]
# <a href="https://colab.research.google.com/github/deekshadaga/forsk_python/blob/master/DTday3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_table('http://bit.ly/chiporders')
data.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
#ipl['winners'].value_counts().idxmax()
#Extract all the data in which 'item name' is containing 'Chicken'
ch_data = data[data['item_name'].str.contains('Chicken')]
ch_data['item_price'].str.replace('$','').astype(float).mean()
# Out:
# 10.133724358974309

# %%
#To check null value in data
data.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
data['choice_description'] = data['choice_description'].fillna('abcde')
data[data['choice_description'].str.contains('Salsa')]
# Out:
#       order_id  ...  item_price
# 4            2  ...     $16.98
# 5            3  ...     $10.98
# 7            4  ...     $11.75
# 8            4  ...      $9.25
# 9            5  ...      $9.25
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [2808 rows x 5 columns]

# %%
#.str.contains() - to comapare particular string value
#.str.replace() - to replace a particular string value in a data frame because typecasting doesn't work in pandas dataframe
#.fillna() - to fill whereever there are null values
#.dtypes      - it will return the data types
#.astypes()   - it will convert a data type of a pandas data series into another
data.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
data['item_price'].str.replace('$','').astype(float).sum()
# Out:
# 34500.16

# %%
movie=pd.read_csv('http://bit.ly/imdbratings')
movie.head()
# Out:
#    star_rating  ...                                        actors_list
# 0          9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1          9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2          9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3          9.0  ...  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4          8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#
# [5 rows x 6 columns]

# %%
#rating >8.0 and genre = comedy or crime
movie[(movie['star_rating']>8.0) & ((movies['genre']== 'Crime') | (movies['genre']=='Comedy'))]
# Out:
#      star_rating  ...                                        actors_list
# 0            9.3  ...  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1            9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2            9.1  ...  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4            8.9  ...  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 21           8.7  ...  [u'Alexandre Rodrigues', u'Matheus Nachtergael...
# ..           ...  ...                                                ...
# 282          8.1  ...   [u'Ruth Gordon', u'Bud Cort', u'Vivian Pickles']
# 285          8.1  ...  [u'Katharine Hepburn', u'Cary Grant', u'Charle...
# 287          8.1  ...  [u'Cary Grant', u'Rosalind Russell', u'Ralph B...
# 290          8.1  ...  [u'Hugh Jackman', u'Jake Gyllenhaal', u'Viola ...
# 293          8.1  ...    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
#
# [81 rows x 6 columns]

# %%
#rating<7.0 and duration <160 
movie[(movie['star_rating']<7.0) & (movies['duration']<160)]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
#movies of actor marlon brando
movie[movie['actors_list'].str.contains('Marlon Brando')]
# Out:
#      star_rating  ...                                        actors_list
# 1            9.2  ...    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 51           8.5  ...  [u'Martin Sheen', u'Marlon Brando', u'Robert D...
# 122          8.3  ...  [u'Marlon Brando', u'Karl Malden', u'Lee J. Co...
# 284          8.1  ...  [u'Vivien Leigh', u'Marlon Brando', u'Kim Hunt...
#
# [4 rows x 6 columns]

# %%
titanic=pd.read_csv('http://bit.ly/kaggletrain')
titanic
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
#seperate the surname from the name
surname=[]
for i in titanic['Name']:
    surname.append(i.split(',')[0])
print(surname)
# Out:
# ['Braund', 'Cumings', 'Heikkinen', 'Futrelle', 'Allen', 'Moran', 'McCarthy', 'Palsson', 'Johnson', 'Nasser', 'Sandstrom', 'Bonnell', 'Saundercock', 'Andersson', 'Vestrom', 'Hewlett', 'Rice', 'Williams', 'Vander Planke', 'Masselmani', 'Fynney', 'Beesley', 'McGowan', 'Sloper', 'Palsson', 'Asplund', 'Emir', 'Fortune', "O'Dwyer", 'Todoroff', 'Uruchurtu', 'Spencer', 'Glynn', 'Wheadon', 'Meyer', 'Holverson', 'Mamee', 'Cann', 'Vander Planke', 'Nicola-Yarred', 'Ahlin', 'Turpin', 'Kraeff', 'Laroche', 'Devaney', 'Rogers', 'Lennon', "O'Driscoll", 'Samaan', 'Arnold-Franchi', 'Panula', 'Nosworthy', 'Harper', 'Faunthorpe', 'Ostby', 'Woolner', 'Rugg', 'Novel', 'West', 'Goodwin', 'Sirayanian', 'Icard', 'Harris', 'Skoog', 'Stewart', 'Moubarek', 'Nye', 'Crease', 'Andersson', 'Kink', 'Jenkin', 'Goodwin', 'Hood', 'Chronopoulos', 'Bing', 'Moen', 'Staneff', 'Moutal', 'Caldwell', 'Dowdell', 'Waelens', 'Sheerlinck', 'McDermott', 'Carrau', 'Ilett', 'Backstrom', 'Ford', 'Slocovski', 'Fortune', 'Celotti', 'Chr
# ...

# %%
#creating new column in titanic
titanic['surname']=surname

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked    surname
# 0              1         0       3  ...   NaN        S     Braund
# 1              2         1       1  ...   C85        C    Cumings
# 2              3         1       3  ...   NaN        S  Heikkinen
# 3              4         1       1  ...  C123        S   Futrelle
# 4              5         0       3  ...   NaN        S      Allen
# ..           ...       ...     ...  ...   ...      ...        ...
# 886          887         0       2  ...   NaN        S   Montvila
# 887          888         1       1  ...   B42        S     Graham
# 888          889         0       3  ...   NaN        S   Johnston
# 889          890         1       1  ...  C148        C       Behr
# 890          891         0       3  ...   NaN        Q     Dooley
#
# [891 rows x 13 columns]

# %%
#if we want to add it at a particular index
titanic.insert(2,'lname',surname)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-3c449c614914> in <module>()
# ----> 1 titanic.insert(2,'lname',surname)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError(f"cannot insert {item}, already exists")
# ...

# %%
titanic
# Out:
#      PassengerId  Survived      lname  ...  Cabin Embarked    surname
# 0              1         0     Braund  ...    NaN        S     Braund
# 1              2         1    Cumings  ...    C85        C    Cumings
# 2              3         1  Heikkinen  ...    NaN        S  Heikkinen
# 3              4         1   Futrelle  ...   C123        S   Futrelle
# 4              5         0      Allen  ...    NaN        S      Allen
# ..           ...       ...        ...  ...    ...      ...        ...
# 886          887         0   Montvila  ...    NaN        S   Montvila
# 887          888         1     Graham  ...    B42        S     Graham
# 888          889         0   Johnston  ...    NaN        S   Johnston
# 889          890         1       Behr  ...   C148        C       Behr
# 890          891         0     Dooley  ...    NaN        Q     Dooley
#
# [891 rows x 14 columns]

# %%
titanic['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic['Sex'].valuecounts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-cc01b0e1b94d> in <module>()
# ----> 1 titanic['Sex'].valuecounts()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'valuecounts'

# %%
titanic.drop(columns='lname')
#or
#column axis=1 and row axis is 0
titanic.drop(['lname'],axis=1)
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked    surname
# 0              1         0       3  ...   NaN        S     Braund
# 1              2         1       1  ...   C85        C    Cumings
# 2              3         1       3  ...   NaN        S  Heikkinen
# 3              4         1       1  ...  C123        S   Futrelle
# 4              5         0       3  ...   NaN        S      Allen
# ..           ...       ...     ...  ...   ...      ...        ...
# 886          887         0       2  ...   NaN        S   Montvila
# 887          888         1       1  ...   B42        S     Graham
# 888          889         0       3  ...   NaN        S   Johnston
# 889          890         1       1  ...  C148        C       Behr
# 890          891         0       3  ...   NaN        Q     Dooley
#
# [891 rows x 13 columns]
